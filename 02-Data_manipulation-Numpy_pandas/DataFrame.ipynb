# %%
#as long the sheet has more than one column, then it is called data frame.

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# # Creating a dataframe

# %%
mydata = np.random.randint(0,101,(4,3))#(4,3) 4 is row 3 is column
my_index = ['CA', 'NY', 'AZ', 'TX']
my_col = ['Jan', 'Feb', 'May']#col is short for column
df = pd. DataFrame(data=mydata, index=my_index, columns=my_col)#df is short for data frame
df
# Out:
#     Jan  Feb  May
# CA   82   31    8
# NY   71    3   59
# AZ   18   53   45
# TX   75    5    6

# %% [markdown]
# # Read .csv file

# %%
df = pd.read_csv('tips.csv')
df
#it shows the first 5 and last 5 rows so it wont show it all because it could be way too long
#in 244 rows and 11 columns, it does not include the title row or the index column
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# # Assignment1

# %%
#read the nba csv file

# %%
#explain the details of the features

# %%
#write the description of our dataset (objective truth)

# %%
#according to the study of our dataset, propose at least two topics that I can research through our dataset

# %% [markdown]
# # data frame: obtain basic information

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 11

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.head(10)
#asking for the first 10
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7       26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8       15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9       14.78  3.23    Male     No  Sun  Dinner     2              7.39
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# ...

# %%
df.tail(10)
#asking for the last 10
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2             16.42
# 238       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 234    Tracy Douglas  4097938155941930    Sat7220
# ...

# %%
len(df)#gives you the number of rows
# Out:
# 244

# %% [markdown]
# # selection and indexing

# %%
df['smoker'].head(20)#grabbing a single column
# Out:
# 0     No
# 1     No
# 2     No
# 3     No
# 4     No
# 5     No
# 6     No
# 7     No
# 8     No
# 9     No
# 10    No
# 11    No
# 12    No
# 13    No
# 14    No
# 15    No
# 16    No
# 17    No
# 18    No
# 19    No
# Name: smoker, dtype: object

# %%
type(df['total_bill'])
# Out:
# pandas.core.series.Series

# %%
#grabbing multiple columns
df[['smoker','total_bill']]
# Out:
#     smoker  total_bill
# 0       No       16.99
# 1       No       10.34
# 2       No       21.01
# 3       No       23.68
# 4       No       24.59
# ..     ...         ...
# 239     No       29.03
# 240    Yes       27.18
# 241    Yes       22.67
# 242     No       17.82
# 243     No       18.78
#
# [244 rows x 2 columns]

# %% [markdown]
# # Creating a new feature

# %%
df['tip_percentage'] = 100

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959             100
# 1      Douglas Tucker  4478071379779230    Sun4608             100
# 2      Travis Walters  6011812112971322    Sun4458             100
# 3    Nathaniel Harris  4676137647685994    Sun5260             100
# 4        Tonya Carter  4832732618637221    Sun2251             100

# %%
df['tip_percentage'] = 100* df['tip'] / df['total_bill']

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959        5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608       16.054159
# 2      Travis Walters  6011812112971322    Sun4458       16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260       13.978041
# 4        Tonya Carter  4832732618637221    Sun2251       14.680765

# %% [markdown]
# # Adjusting existing columns

# %%
df['price_per_person'] = np.round(df['price_per_person'],1)

# %% [markdown]
# # How to remove a column

# %%
df = df.drop('tip_percentage',axis=1)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2               8.5
# 1       10.34  1.66    Male     No  Sun  Dinner     3               3.4
# 2       21.01  3.50    Male     No  Sun  Dinner     3               7.0
# 3       23.68  3.31    Male     No  Sun  Dinner     2              11.8
# 4       24.59  3.61  Female     No  Sun  Dinner     4               6.2
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# # Set Index

# %%
df.set_index('Payment ID')
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                  8.5  Christy Cunningham  3560325168603410
# ...

# %% [markdown]
# # Reset Index

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#    index  total_bill   tip     sex smoker  day    time  size  \
# 0      0       16.99  1.01  Female     No  Sun  Dinner     2
# 1      1       10.34  1.66    Male     No  Sun  Dinner     3
# 2      2       21.01  3.50    Male     No  Sun  Dinner     3
# 3      3       23.68  3.31    Male     No  Sun  Dinner     2
# 4      4       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number Payment ID
# 0               8.5  Christy Cunningham  3560325168603410    Sun2959
# 1               3.4      Douglas Tucker  4478071379779230    Sun4608
# 2               7.0      Travis Walters  6011812112971322    Sun4458
# 3              11.8    Nathaniel Harris  4676137647685994    Sun5260
# 4               6.2        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# # Grabbing a single row

# %%
df.iloc[0]
# Out:
# index                                0
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                   8.5
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Payment ID                     Sun2959
# Name: 0, dtype: object

# %% [markdown]
# # Grabbing Multiple rows

# %%
df.iloc[0:4]
# Out:
#    index  total_bill   tip     sex smoker  day    time  size  \
# 0      0       16.99  1.01  Female     No  Sun  Dinner     2
# 1      1       10.34  1.66    Male     No  Sun  Dinner     3
# 2      2       21.01  3.50    Male     No  Sun  Dinner     3
# 3      3       23.68  3.31    Male     No  Sun  Dinner     2
#
#    price_per_person          Payer Name         CC Number Payment ID
# 0               8.5  Christy Cunningham  3560325168603410    Sun2959
# 1               3.4      Douglas Tucker  4478071379779230    Sun4608
# 2               7.0      Travis Walters  6011812112971322    Sun4458
# 3              11.8    Nathaniel Harris  4676137647685994    Sun5260

# %% [markdown]
# # Remove a row

# %% [markdown]
# # Conditional Filter

# %% [markdown]
# ## Single Condition

# %%
bool_series = df['tip'] > 5
bool_series
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239     True
# 240    False
# 241    False
# 242    False
# 243    False
# Name: tip, Length: 244, dtype: bool

# %%
df[bool_series]
# Out:
#      index  total_bill    tip     sex smoker   day    time  size  \
# 23      23       39.42   7.58    Male     No   Sat  Dinner     4
# 44      44       30.40   5.60    Male     No   Sun  Dinner     4
# 47      47       32.40   6.00    Male     No   Sun  Dinner     4
# 52      52       34.81   5.20  Female     No   Sun  Dinner     4
# 59      59       48.27   6.73    Male     No   Sat  Dinner     4
# 85      85       34.83   5.17  Female     No  Thur   Lunch     4
# 88      88       24.71   5.85    Male     No  Thur   Lunch     2
# 116    116       29.93   5.07    Male     No   Sun  Dinner     4
# 141    141       34.30   6.70    Male     No  Thur   Lunch     6
# 155    155       29.85   5.14  Female     No   Sun  Dinner     5
# 170    170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 172    172        7.25   5.15    Male    Yes   Sun  Dinner     2
# 181    181       23.33   5.65    Male    Yes   Sun  Dinner     2
# ...

# %%
df[df['tip'] > 5]
#this is the prefered way to filter out
# Out:
#      index  total_bill    tip     sex smoker   day    time  size  \
# 23      23       39.42   7.58    Male     No   Sat  Dinner     4
# 44      44       30.40   5.60    Male     No   Sun  Dinner     4
# 47      47       32.40   6.00    Male     No   Sun  Dinner     4
# 52      52       34.81   5.20  Female     No   Sun  Dinner     4
# 59      59       48.27   6.73    Male     No   Sat  Dinner     4
# 85      85       34.83   5.17  Female     No  Thur   Lunch     4
# 88      88       24.71   5.85    Male     No  Thur   Lunch     2
# 116    116       29.93   5.07    Male     No   Sun  Dinner     4
# 141    141       34.30   6.70    Male     No  Thur   Lunch     6
# 155    155       29.85   5.14  Female     No   Sun  Dinner     5
# 170    170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 172    172        7.25   5.15    Male    Yes   Sun  Dinner     2
# 181    181       23.33   5.65    Male    Yes   Sun  Dinner     2
# ...

# %%
df[df['sex'] == 'Male']
# Out:
#      index  total_bill   tip   sex smoker  day    time  size  \
# 1        1       10.34  1.66  Male     No  Sun  Dinner     3
# 2        2       21.01  3.50  Male     No  Sun  Dinner     3
# 3        3       23.68  3.31  Male     No  Sun  Dinner     2
# 5        5       25.29  4.71  Male     No  Sun  Dinner     4
# 6        6        8.77  2.00  Male     No  Sun  Dinner     2
# ..     ...         ...   ...   ...    ...  ...     ...   ...
# 236    236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237    237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239    239       29.03  5.92  Male     No  Sat  Dinner     3
# 241    241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242    242       17.82  1.75  Male     No  Sat  Dinner     2
#
#      price_per_person          Payer Name         CC Number Payment ID
# 1                 3.4      Douglas Tucker  4478071379779230    Sun4608
# 2                 7.0      Travis Walters  6011812112971322    Sun4458
# ...

# %% [markdown]
# # Multiple - Condition

# %%
df[(df['total_bill'] > 30) & (df['sex'] == 'Male')]
# Out:
#      index  total_bill    tip   sex smoker   day    time  size  \
# 23      23       39.42   7.58  Male     No   Sat  Dinner     4
# 39      39       31.27   5.00  Male     No   Sat  Dinner     3
# 44      44       30.40   5.60  Male     No   Sun  Dinner     4
# 47      47       32.40   6.00  Male     No   Sun  Dinner     4
# 56      56       38.01   3.00  Male    Yes   Sat  Dinner     4
# 59      59       48.27   6.73  Male     No   Sat  Dinner     4
# 83      83       32.68   5.00  Male    Yes  Thur   Lunch     2
# 95      95       40.17   4.73  Male    Yes   Fri  Dinner     4
# 112    112       38.07   4.00  Male     No   Sun  Dinner     3
# 141    141       34.30   6.70  Male     No  Thur   Lunch     6
# 142    142       41.19   5.00  Male     No  Thur   Lunch     5
# 156    156       48.17   5.00  Male     No   Sun  Dinner     6
# 167    167       31.71   4.50  Male     No   Sun  Dinner     4
# 170    170       50.81  10.00  Male    Yes   Sat  Dinner     3
# ...

# %%
df[(df['day'] == 'Sun') | (df['day'] == 'Sat')]
# Out:
#      index  total_bill   tip     sex smoker  day    time  size  \
# 0        0       16.99  1.01  Female     No  Sun  Dinner     2
# 1        1       10.34  1.66    Male     No  Sun  Dinner     3
# 2        2       21.01  3.50    Male     No  Sun  Dinner     3
# 3        3       23.68  3.31    Male     No  Sun  Dinner     2
# 4        4       24.59  3.61  Female     No  Sun  Dinner     4
# ..     ...         ...   ...     ...    ...  ...     ...   ...
# 238    238       35.83  4.67  Female     No  Sat  Dinner     3
# 239    239       29.03  5.92    Male     No  Sat  Dinner     3
# 240    240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241    241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242    242       17.82  1.75    Male     No  Sat  Dinner     2
#
#      price_per_person          Payer Name         CC Number Payment ID
# 0                 8.5  Christy Cunningham  3560325168603410    Sun2959
# ...
