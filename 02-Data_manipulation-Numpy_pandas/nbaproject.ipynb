# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('nbadatabase_24_25.csv')
pd.set_option('display.max_columns', None)
df
# Out:
#                  Player   Tm  Opp Res     MP  FG  FGA    FG%  3P  3PA    3P%  \
# 0          Jayson Tatum  BOS  NYK   W  30.30  14   18  0.778   8   11  0.727
# 1         Anthony Davis  LAL  MIN   W  37.58  11   23  0.478   1    3  0.333
# 2         Derrick White  BOS  NYK   W  26.63   8   13  0.615   6   10  0.600
# 3          Jrue Holiday  BOS  NYK   W  30.52   7    9  0.778   4    6  0.667
# 4         Miles McBride  NYK  BOS   L  25.85   8   10  0.800   4    5  0.800
# ...                 ...  ...  ...  ..    ...  ..  ...    ...  ..  ...    ...
# 16507       Emoni Bates  CLE  WAS   W   5.18   0    2  0.000   0    2  0.000
# 16508        A.J. Green  MIL  ATL   L  20.75   1    5  0.200   0    2  0.000
# 16509  Kenrich Williams  OKC  TOR   W  16.70   0    5  0.000   0    3  0.000
# 16510     Tyrese Martin  BRK  MIA   W  20.70   1    5  0.200   0    4  0.000
# 16511       Eric Gordon  PHI  DET   L  10.35   0    4  0.000   0    3  0.000
#
# ...

# %%
df.columns
# Out:
# Index(['Player', 'Tm', 'Opp', 'Res', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA',
#        '3P%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK',
#        'TOV', 'PF', 'PTS', 'GmSc', 'Data'],
#       dtype='object')

# %% [markdown]
# - Player: Name of the player.
# - Tm: Abbreviation of the player's team.
# - Opp: Abbreviation of the opposing team.
# - Res: Result of the game for the player's team.
# - MP: Minutes played, represented as a float (e.g., 23.5 = 23 minutes and 30 seconds).
# - FG: Field goals made.
# - FGA: Field goal attempts.
# - FG%: Field goal percentage.
# - 3P: 3-point field goals made.
# - 3PA: 3-point field goal attempts.
# - 3P%: 3-point shooting percentage.
# - FT: Free throws made.
# - FTA: Free throw attempts.
# - FT%: Free throw percentage.
# - ORB: Offensive rebounds.
# - DRB: Defensive rebounds.
# - TRB: Total rebounds.
# - AST: Assists.
# - STL: Steals.
# - BLK: Blocks.
# - TOV: Turnovers.
# - PF: Personal fouls.
# - PTS: Total points scored.
# - GmSc: Game Score, a metric summarizing player performance for the game.

# %% [markdown]
# # Potential Resource Topic

# %%
#the relationship on how many players on a team with <25 points and if they win
#the realtionship between how many minutes played and how many points a player has
#the amount of playing time and the amount of points they have how it relate to eachother?
#out of the fg%, how many of the shots made were 3 pointers
#how does a players position affect their 3 point percentage

# %% [markdown]
# # 3-5 potential topics

# %% [markdown]
# # Conditional Filter

# %% [markdown]
# ## Single Condition

# %%
df.columns
# Out:
# Index(['Player', 'Tm', 'Opp', 'Res', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA',
#        '3P%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK',
#        'TOV', 'PF', 'PTS', 'GmSc', 'Data'],
#       dtype='object')
